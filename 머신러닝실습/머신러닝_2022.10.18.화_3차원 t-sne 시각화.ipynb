# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_iris
from sklearn.manifold import TSNE

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.family']='Malgun Gothic'
plt.rcParams['axes.unicode_minus']=False

# %%
iris = load_iris()

# %%
df = pd.DataFrame(data = iris.data, columns=iris.feature_names)
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
tsne = TSNE(n_components=2).fit_transform(df)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\user\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %%
tsne
# Out:
# array([[-2.0580135e+01,  2.0908794e+01],
#        [-1.8776745e+01,  1.8723379e+01],
#        [-1.8358683e+01,  1.9829208e+01],
#        [-1.8138710e+01,  1.9249252e+01],
#        [-2.0641880e+01,  2.0801630e+01],
#        [-2.2672539e+01,  2.1271294e+01],
#        [-1.8338730e+01,  2.0268772e+01],
#        [-2.0174463e+01,  2.0221893e+01],
#        [-1.7449818e+01,  1.8954237e+01],
#        [-1.9161970e+01,  1.9173437e+01],
#        [-2.1921144e+01,  2.1721088e+01],
#        [-1.9847366e+01,  1.9578659e+01],
#        [-1.8425367e+01,  1.8816439e+01],
#        [-1.7061855e+01,  1.9442329e+01],
#        [-2.3034668e+01,  2.2398531e+01],
#        [-2.3467001e+01,  2.1988825e+01],
#        [-2.2571112e+01,  2.1777447e+01],
#        [-2.0790182e+01,  2.0739313e+01],
#        [-2.2499378e+01,  2.2280666e+01],
#        [-2.1922859e+01,  2.0830673e+01],
#        [-2.1074928e+01,  2.2001318e+01],
#        [-2.1629555e+01,  2.0636974e+01],
#        [-1.8185680e+01,  2.1082245e+01],
#        [-2.1019972e+01,  1.9483620e+01],
#        [-2.0380964e+01,  1.8839369e+01],
#        [-1.9362509e+01,  1.8593889e+01],
#        [-2.0738283e+01,  1.9816616e+01],
#        [-2.1013586e+01,  2.1137732e+01],
#        [-2.0525747e+01,  2.1255932e+01],
#        [-1.8854164e+01,  1.9425068e+01],
#        [-1.9078968e+01,  1.8970278e+01],
#        [-2.1083817e+01,  2.1886528e+01],
#        [-2.3001537e+01,  2.1126673e+01],
#        [-2.3214546e+01,  2.1791275e+01],
#        [-1.9186272e+01,  1.9222792e+01],
#        [-1.9126299e+01,  2.0352442e+01],
#        [-2.1486921e+01,  2.2236576e+01],
#        [-1.9873430e+01,  2.1022482e+01],
#        [-1.7415661e+01,  1.9278805e+01],
#        [-2.0451593e+01,  2.0464602e+01],
#        [-2.0060877e+01,  2.0888184e+01],
#        [-1.7342300e+01,  1.8186666e+01],
#        [-1.7535009e+01,  1.9823044e+01],
#        [-2.1362511e+01,  1.9722919e+01],
#        [-2.2456985e+01,  2.0223799e+01],
#        [-1.8443428e+01,  1.8819342e+01],
#        [-2.2037638e+01,  2.0781937e+01],
#        [-1.8133055e+01,  1.9675192e+01],
#        [-2.1787592e+01,  2.1420757e+01],
#        [-1.9712553e+01,  2.0208044e+01],
#        [ 4.5016289e+00, -4.7036219e+00],
#        [ 4.4595690e+00, -2.9739959e+00],
#        [ 3.9969501e+00, -4.8323154e+00],
#        [ 7.6293712e+00,  8.9497286e-01],
#        [ 4.2983103e+00, -3.4340534e+00],
#        [ 5.2877707e+00, -7.9120748e-02],
#        [ 3.7877746e+00, -2.6907678e+00],
#        [ 8.0279112e+00,  2.5471823e+00],
#        [ 4.6622562e+00, -3.6931360e+00],
#        [ 7.8863564e+00,  1.1279436e+00],
#        [ 8.2226524e+00,  2.3039412e+00],
#        [ 5.5274768e+00, -6.1750054e-01],
#        [ 7.6376619e+00, -1.1952675e-01],
#        [ 4.1811152e+00, -2.0121112e+00],
#        [ 6.6759405e+00,  1.6975846e+00],
#        [ 3.7489620e-01, -5.6956110e+00],
#        [ 2.5992689e+00, -2.0910735e+00],
#        [ 1.4391884e-01, -6.9847059e+00],
#        [ 2.0662207e-02, -7.4529252e+00],
#        [ 1.0629400e+00, -6.8804069e+00],
#        [ 1.2248389e+00, -2.1936584e+00],
#        [-6.5760607e-01, -7.8404098e+00],
#        [-4.2251069e-02, -7.9568696e+00],
#        [ 8.5678893e-01, -6.7495956e+00],
#        [ 1.6662681e+00, -3.6483073e+00],
#        [ 1.0868882e+00, -5.8862658e+00],
#        [ 1.1292754e+00, -7.6379600e+00],
#        [ 1.8490002e+00, -2.1590519e+00]], dtype=float32)

# %%
tsne_df = pd.DataFrame(tsne, columns=['component0', 'component1'])
tsne_df
# Out:
#      component0  component1
# 0     23.741606   -7.379366
# 1     21.306580   -6.659800
# 2     21.030148   -7.753096
# 3     20.741821   -7.510865
# 4     23.793039   -7.881887
# ..          ...         ...
# 145  -15.571315    0.212376
# 146  -13.111645    2.340697
# 147  -14.877629    0.776938
# 148  -15.875941   -0.703385
# 149  -12.133493    3.501014
#
# [150 rows x 2 columns]

# %% [markdown]
# ### t-sne 2차원 데이터 시각화

# %%
tsne_df['target'] = iris.target

# %%
tsne_df_0 = tsne_df[tsne_df['target']==0]
tsne_df_1 = tsne_df[tsne_df['target']==1]
tsne_df_2 = tsne_df[tsne_df['target']==2] # 타겟 값 다르게 줘야함

# %%
plt.scatter(tsne_df_0['component0'], tsne_df_0['component1'],
           color = 'pink', label = 'setosa')
plt.scatter(tsne_df_1['component0'], tsne_df_1['component1'], 
           color = 'purple', label = 'versicolor')
plt.scatter(tsne_df_2['component0'], tsne_df_2['component1'], 
           color = 'yellow', label = 'virginica')

plt.xlabel('component0')
plt.ylabel('component1')
plt.legend()
plt.show()

# %% [markdown]
# ### 3차원 t-sne 시각화

# %%
# t-sne 모델 불러오기
# 학습 + 변환 -> 동시에
# 데이터프레임 변환시킨 데이터 바꾸기
# 컬럼명 = component0, component1, component2

# %%
tsne = TSNE(n_components=3).fit_transform(df) # 3차원으로 정의
# Out:
# C:\Users\user\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\user\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %%
tsne_df = pd.DataFrame(tsne, 
                       columns=['component0', 'component1', 'component2'])

tsne_df
# Out:
#      component0  component1  component2
# 0    -39.132744  -37.816959  -80.267586
# 1    -34.599812 -140.229736  -85.100296
# 2    -82.308876  -43.438171 -129.992264
# 3    -75.091812 -115.995659  -91.021133
# 4    -71.089828  -10.408429  -90.369453
# ..          ...         ...         ...
# 145   83.018204  -29.507050 -101.100052
# 146   11.410493   66.073441   33.833481
# 147   61.920395   83.769928   29.106216
# 148  172.709030   15.386853  -20.494205
# 149  -51.221241   51.988586   11.432148
#
# [150 rows x 3 columns]

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
tsne_df['target'] = iris.target

# %%
fig = plt.figure(figsize=(9,6))
ax = fig.add_subplot(111, projection='3d')

tsne_df_0 = tsne_df[tsne_df['target']==0]
tsne_df_1 = tsne_df[tsne_df['target']==1]
tsne_df_2 = tsne_df[tsne_df['target']==2]

ax.scatter(tsne_df_0['component0'], tsne_df_0['component1'], tsne_df_0['component2'],
           color = 'pink', label = 'setosa')
ax.scatter(tsne_df_1['component0'], tsne_df_1['component1'], tsne_df_0['component2'],
           color = 'purple', label = 'versicolor')
ax.scatter(tsne_df_2['component0'], tsne_df_2['component1'], tsne_df_0['component2'],
           color = 'yellow', label = 'virginica')

ax.set_xlabel('component0')
ax.set_ylabel('component1')
ax.set_zlabel('component2')
ax.legend()
plt.show()
